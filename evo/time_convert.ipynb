# %%
import numpy as np

# %%
f = open("./data/orbslam07.txt", "r")
f2 = open("./data/orbslam07_c.txt", "w")
first = False
first_time = None
for line in f:
    element = line.split()
    if (first == False):
        first = True
        first_time = float(element[0])
    time_convert = float(element[0]) - first_time
    print(time_convert)
    element[0] = "{:e}".format(time_convert)
    print(element[0] )
    element.append('\n')
    for i in element: 
        f2.write(i)
        f2.write(" ")
f2.close()
f.close()
# Out:
# 0.0
# 0.000000e+00
# 0.4156219959259033
# 4.156220e-01
# 0.6233770847320557
# 6.233771e-01
# 0.934622049331665
# 9.346220e-01
# 1.245873212814331
# 1.245873e+00
# 1.4532530307769775
# 1.453253e+00
# 1.86800217628479
# 1.868002e+00
# 2.075498104095459
# 2.075498e+00
# 2.2828750610351562
# 2.282875e+00
# 2.4901440143585205
# 2.490144e+00
# 2.697329044342041
# 2.697329e+00
# 3.0082480907440186
# 3.008248e+00
# 3.2157511711120605
# 3.215751e+00
# 3.423125982284546
# 3.423126e+00
# 3.630648136138916
# 3.630648e+00
# 3.942121982574463
# 3.942122e+00
# 4.150266170501709
# 4.150266e+00
# 4.3585121631622314
# 4.358512e+00
# 4.566884994506836
# 4.566885e+00
# 4.671250104904175
# 4.671250e+00
# 5.505748987197876
# 5.505749e+00
# 5.8183770179748535
# 5.818377e+00
# 6.130876064300537
# 6.130876e+00
# 6.443143129348755
# 6.443143e+00
# 6.651280164718628
# 6.651280e+00
# 6.859377145767212
# 6.859377e+00
# 7.171256065368652
# 7.171256e+00
# 7.379271984100342
# 7.379272e+00
# 7.691129207611084
# ...
